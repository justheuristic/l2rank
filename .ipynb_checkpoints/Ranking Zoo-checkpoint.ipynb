# %%
# %pylab inline
from time import time
import numpy as np
import matplotlib.pyplot as plt
import  pandas
import h5py
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sklearn.externals import joblib
from sklearn.metrics import mean_squared_error
from sklearn.cross_validation import train_test_split

# %% [markdown]
# ## Load the data. One fold for now

# %%
def save_as_h5(path_to_txt,output_name="mslr"):
    
    print "opening "+path_to_txt
    f = open(path_to_txt)
    labels = []
    features = []
    print "extracting..."
    for line in f:
        line = line[:line.find('#') - 1]#удалить комменты из конца линии
        ls = line.split()
        labels.append(int(ls[0]))
        features.append([float(x[x.find(':') + 1:]) for x in ls[1:]])
    f.close()
    print "converting..."
    labels = np.asarray(labels, dtype=np.int32)
    features = np.asarray(features)
    query = features[:, 0].astype(int)
    features = features[:, 1:]
    print "saving..."
    h5f = h5py.File(output_name, 'w')
    h5f.create_dataset('qids', data=query)
    h5f.create_dataset('labels', data=labels)
    h5f.create_dataset('features', data=features)
    h5f.close()
    print "done"
    return features,query,labels

# %%
def load_h5(name):
    print "reading from",name
    h5f = h5py.File(name,'r')
    labels = h5f['labels'][:]
    qids = h5f['qids'][:]
    features = h5f['features'][:]
    h5f.close()
    print "done"
    return features,qids,labels

# %%
# %%time
##warning! this can take a long time. no need to rerun that code if u have CSV files created once.
#save_as_h5("MSLR10/Fold1/train.txt","mslr_train")
#save_as_h5("MSLR10/Fold1/test.txt","mslr_test")
#save_as_h5("MSLR10/Fold1/vali.txt","mslr_vali")
#print "converted that"
# Out:
# Wall time: 0 ns

# %%
Xtr,Qtr,Ytr = load_h5("mslr_train")#smallest one 4 speed purpose
Xts,Qts,Yts = load_h5("mslr_vali")
# Out:
# reading from mslr_train
# done
# reading from mslr_vali
# done

# %%
print "train: ",Xtr.shape,"qids:",len(set(Qtr))
print "test: ",Xts.shape,"qids:",len(set(Qts))
print "qid intersection:",len(set.intersection(set(Qtr),set(Qts))),"(must be 0)"
# Out:
# train:  (723412L, 136L) qids: 6000
# test:  (235259L, 136L) qids: 2000
# qid intersection: 0 (must be 0)

# %% [markdown]
# # Metrics & scoring

# %%
from metrics import roc_auc_score, mean_ndcg #def mean_ndcg(y_true, y_pred, query_ids, rank=None)

# %%
def score(model, X, Y, qid):
    Ypred = model.predict(X)

    print "NDCG5   :", mean_ndcg(Y, Ypred, qid, rank=5)
    print "NDCG10  :", mean_ndcg(Y, Ypred, qid, rank=10)
    print "NDCGfull:", mean_ndcg(Y, Ypred, qid, rank=None)
    print "rank AUC:", roc_auc_score(Y, Ypred)
    
    print "MSE     :", mean_squared_error(Y,Ypred)

# %%
def learning_curve_ndcg(model, X, y, qid, rank=10):
    """stolen from some GIT repo"""
    max_n_trees = len(model.estimators_)
    scores = []
    
    if hasattr(model, 'staged_predict'):
        #for boosting ensembles
        n_trees = np.arange(max_n_trees) + 1
        for y_predicted in model.staged_predict(X):
            scores.append(mean_ndcg(y, y_predicted, qid, rank=10))
    else:
        y_predicted= np.zeros(len(y)).astype(float)
        n_trees = np.arange(max_n_trees) + 1
        
        for i in xrange(max_n_trees):
            y_predicted += model.estimators_[i].predict(X)
            scores.append(mean_ndcg(y, y_predicted, qid, rank=rank))
            
    plt.plot(n_trees, scores)
    plt.xlabel("Number of trees")
    plt.ylabel("NDCG-"+ str(rank))
    _ = plt.title("NDCG learning curve")

# %% [markdown]
# # Model training & evaluation

# %% [markdown]
# ## Random Forest (mse)

# %%
# %%time
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators=300, min_samples_split=5, random_state=1, n_jobs=-1)
rfr.fit(Xtr, Ytr)#only 2 cores and the unlimited tree growth. Don't take it for a benchmark time
# Out:
# Wall time: 2h 57min 10s

# %%
# %%time
print "train:"
score(rfr,Xtr,Ytr,Qtr)
print "test"
score(rfr,Xts,Yts,Qts)
# Out:
# train:
# NDCG5   : 0.962890258751
# NDCG10  : 0.964880810411
# NDCGfull: 0.967711780659
# rank AUC: 0.998324836223
# MSE     : 0.0882226223775
# test
# NDCG5   : 0.53240505746
# NDCG10  : 0.537172321678
# NDCGfull: 0.756809636057
# rank AUC: 0.707383041804
# MSE     : 0.563196769229
# Wall time: 23min 46s

# %%
# %%time
learning_curve_ndcg(rfr,Xts,Yts,Qts,rank = 10)
# Out:
# Wall time: 2min 41s

# %% [raw]
# Gradient Boost (mse)

# %%
# %%time
from sklearn.ensemble import GradientBoostingRegressor
gb = GradientBoostingRegressor(learning_rate=0.07,loss='ls',n_estimators=300, max_depth=6,
                                verbose=0, subsample=0.5, random_state=42)#verbose >= 2 to show OOB scores
gb.fit(Xtr, Ytr)
# Out:
# Wall time: 4h 35min 13s

# %%
# %%time
print "train:"
score(gb,Xtr,Ytr,Qtr)
print "test"
score(gb,Xts,Yts,Qts)
# Out:
# train:
# NDCG5   : 0.583676684197
# NDCG10  : 0.583487300767
# NDCGfull: 0.776343395486
# rank AUC: 0.744370237002
# MSE     : 0.507702302658
# test
# NDCG5   : 0.547281080165
# NDCG10  : 0.551430456266
# NDCGfull: 0.763919638237
# rank AUC: 0.716070445639
# MSE     : 0.555989334707
# Wall time: 1min 11s

# %%
# %%time
learning_curve_ndcg(gb,Xts,Yts,Qts,rank = 10)
# Out:
# Wall time: 1min 21s

# %% [markdown]
# # LambdaMart (ndcg)

# %%
# %%time
from lambdamart import LambdaMART

lmart= LambdaMART(n_estimators=300, max_depth=6,
                  learning_rate=0.07, max_rank=50,gain = "exponential")
lmart.fit(Xtr,Ytr,Q=Qtr)
# Out:
# Wall time: 5h 36min 9s

# %%
# %%time
print "train:"
score(lmart,Xtr,Ytr,Qtr)
print "test"
score(lmart,Xts,Yts,Qts)
# Out:
# train:
# NDCG5   : 0.57858264102
# NDCG10  : 0.572677401566
# NDCGfull: 0.771953314128
# rank AUC: 0.70949052636
# MSE     : 2.42600486927
# test
# NDCG5   : 0.543734839342
# NDCG10  : 0.546785789488
# NDCGfull: 0.762256815157
# rank AUC: 0.699408098044
# MSE     : 2.46519581237
# Wall time: 1min 11s

# %%
# %%time
learning_curve_ndcg(lmart,Xts,Yts,Qts,rank = 10)
# Out:
# Wall time: 1min 22s

# %% [markdown]
# ## Bagged GBDT (mse)

# %%
# %%time
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import GradientBoostingRegressor
gb = GradientBoostingRegressor(learning_rate=0.07,loss='ls',n_estimators=200, max_depth=6,
                                verbose=0)#verbose >= 2 to show OOB scores
bgb = BaggingRegressor(base_estimator=gb,n_estimators=30,n_jobs =-1, max_samples = 0.33)
bgb.fit(Xtr, Ytr)
# Out:
# Wall time: 12h 4min 14s

# %%
# %%time
print "train:"
score(bgb,Xtr,Ytr,Qtr)
print "test"
score(bgb,Xts,Yts,Qts)
# Out:
# train:
# NDCG5   : 0.56652287947
# NDCG10  : 0.568011872348
# NDCGfull: 0.76988575237
# rank AUC: 0.734829096502
# MSE     : 0.524091505637
# test
# NDCG5   : 0.547253586632
# NDCG10  : 0.551595441615
# NDCGfull: 0.763109113992
# rank AUC: 0.714736076729
# MSE     : 0.558514515858
# Wall time: 19min 38s

# %%
# %%time
learning_curve_ndcg(bgb,Xts,Yts,Qts,rank = 10)
# Out:
# Wall time: 3min 19s

# %%
from sklearn.externals import joblib
joblib.dump(bgb, 'dumps/fullscale_trained_bgb.pkl')

# %% [markdown]
# ## bagged lmart (nDCG)

# %%
# %%time
from lambdamart import LambdaMART
from bagged_ranking import BaggingRanker
lmart= LambdaMART(n_estimators=200, max_depth=6,
                  learning_rate=0.07,  max_rank=100,gain = "exponential")
blmart = BaggingRanker(base_estimator=lmart,n_estimators=30,sample_whole_queries=True,bootstrap=True,n_jobs =-1,max_samples=0.33)

blmart.fit(Xtr,Ytr,Q = Qtr)
# Out:
# Wall time: 7h 18min 25s

# %%
# %%time
print "train:"
score(blmart,Xtr,Ytr,Qtr)
print "test"
score(blmart,Xts,Yts,Qts)
# Out:
# train:
# NDCG5   : 0.558204699035
# NDCG10  : 0.554818036709
# NDCGfull: 0.764859317718
# rank AUC: 0.70475212546
# MSE     : 2.32828989478
# test
# NDCG5   : 0.540636881727
# NDCG10  : 0.54281380228
# NDCGfull: 0.761355778246
# rank AUC: 0.69520646883
# MSE     : 2.35731560686
# Wall time: 21min 50s

# %%
# %%time
learning_curve_ndcg(blmart,Xts,Yts,Qts,rank = 10)
# Out:
# Wall time: 3min 18s

# %%
from sklearn.externals import joblib
joblib.dump(blmart, 'dumps/fullscale_trained_blmart.pkl')
# Out:
# ['dumps/fullscale_trained_blmart.pkl',
#  'dumps/fullscale_trained_blmart.pkl_01.npy',
#  'dumps/fullscale_trained_blmart.pkl_02.npy',
#  'dumps/fullscale_trained_blmart.pkl_03.npy',
#  'dumps/fullscale_trained_blmart.pkl_04.npy',
#  'dumps/fullscale_trained_blmart.pkl_05.npy',
#  'dumps/fullscale_trained_blmart.pkl_06.npy',
#  'dumps/fullscale_trained_blmart.pkl_07.npy',
#  'dumps/fullscale_trained_blmart.pkl_08.npy',
#  'dumps/fullscale_trained_blmart.pkl_09.npy',
#  'dumps/fullscale_trained_blmart.pkl_10.npy',
#  'dumps/fullscale_trained_blmart.pkl_11.npy',
#  'dumps/fullscale_trained_blmart.pkl_12.npy',
#  'dumps/fullscale_trained_blmart.pkl_13.npy',
#  'dumps/fullscale_trained_blmart.pkl_14.npy',
#  'dumps/fullscale_trained_blmart.pkl_15.npy',
#  'dumps/fullscale_trained_blmart.pkl_16.npy',
#  'dumps/fullscale_trained_blmart.pkl_17.npy',
#  'dumps/fullscale_trained_blmart.pkl_18.npy',
#  'dumps/fullscale_trained_blmart.pkl_19.npy',
#  'dumps/fullscale_trained_blmart.pkl_20.npy',
#  'dumps/fullscale_trained_blmart.pkl_21.npy',
#  'dumps/fullscale_trained_blmart.pkl_22.npy',
#  'dumps/fullscale_trained_blmart.pkl_23.npy',
#  'dumps/fullscale_trained_blmart.pkl_24.npy',
#  'dumps/fullscale_trained_blmart.pkl_25.npy',
#  'dumps/fullscale_trained_blmart.pkl_26.npy',
#  'dumps/fullscale_trained_blmart.pkl_27.npy',
#  'dumps/fullscale_trained_blmart.pkl_28.npy',
#  'dumps/fullscale_trained_blmart.pkl_29.npy',
#  'dumps/fullscale_trained_blmart.pkl_30.npy',
#  'dumps/fullscale_trained_blmart.pkl_31.npy',
#  'dumps/fullscale_trained_blmart.pkl_32.npy',
#  'dumps/fullscale_trained_blmart.pkl_33.npy',
#  'dumps/fullscale_trained_blmart.pkl_34.npy',
#  'dumps/fullscale_trained_blmart.pkl_35.npy',
#  'dumps/fullscale_trained_blmart.pkl_36.npy',
#  'dumps/fullscale_trained_blmart.pkl_37.npy',
#  'dumps/fullscale_trained_blmart.pkl_38.npy',
#  'dumps/fullscale_trained_blmart.pkl_39.npy',
#  'dumps/fullscale_trained_blmart.pkl_40.npy',
#  'dumps/fullscale_trained_blmart.pkl_41.npy',
#  'dumps/fullscale_trained_blmart.pkl_42.npy',
#  'dumps/fullscale_trained_blmart.pkl_43.npy',
#  'dumps/fullscale_trained_blmart.pkl_44.npy',
#  'dumps/fullscale_trained_blmart.pkl_45.npy',
#  'dumps/fullscale_trained_blmart.pkl_46.npy',
#  'dumps/fullscale_trained_blmart.pkl_47.npy',
#  'dumps/fullscale_trained_blmart.pkl_48.npy',
#  'dumps/fullscale_trained_blmart.pkl_49.npy',
#  'dumps/fullscale_trained_blmart.pkl_50.npy',
#  'dumps/fullscale_trained_blmart.pkl_51.npy',
#  'dumps/fullscale_trained_blmart.pkl_52.npy',
#  'dumps/fullscale_trained_blmart.pkl_53.npy',
#  'dumps/fullscale_trained_blmart.pkl_54.npy',
#  'dumps/fullscale_trained_blmart.pkl_55.npy',
#  'dumps/fullscale_trained_blmart.pkl_56.npy',
#  'dumps/fullscale_trained_blmart.pkl_57.npy',
#  'dumps/fullscale_trained_blmart.pkl_58.npy',
#  'dumps/fullscale_trained_blmart.pkl_59.npy',
#  'dumps/fullscale_trained_blmart.pkl_60.npy',
#  'dumps/fullscale_trained_blmart.pkl_61.npy',
#  'dumps/fullscale_trained_blmart.pkl_62.npy',
#  'dumps/fullscale_trained_blmart.pkl_63.npy',
#  'dumps/fullscale_trained_blmart.pkl_64.npy',
#  'dumps/fullscale_trained_blmart.pkl_65.npy',
#  'dumps/fullscale_trained_blmart.pkl_66.npy',
#  'dumps/fullscale_trained_blmart.pkl_67.npy',
#  'dumps/fullscale_trained_blmart.pkl_68.npy',
#  'dumps/fullscale_trained_blmart.pkl_69.npy',
#  'dumps/fullscale_trained_blmart.pkl_70.npy',
#  'dumps/fullscale_trained_blmart.pkl_71.npy',
#  'dumps/fullscale_trained_blmart.pkl_72.npy',
#  'dumps/fullscale_trained_blmart.pkl_73.npy',
#  'dumps/fullscale_trained_blmart.pkl_74.npy',
#  'dumps/fullscale_trained_blmart.pkl_75.npy',
#  'dumps/fullscale_trained_blmart.pkl_76.npy',
#  'dumps/fullscale_trained_blmart.pkl_77.npy',
#  'dumps/fullscale_trained_blmart.pkl_78.npy',
#  'dumps/fullscale_trained_blmart.pkl_79.npy',
#  'dumps/fullscale_trained_blmart.pkl_80.npy',
#  'dumps/fullscale_trained_blmart.pkl_81.npy',
#  'dumps/fullscale_trained_blmart.pkl_82.npy',
#  'dumps/fullscale_trained_blmart.pkl_83.npy',
#  'dumps/fullscale_trained_blmart.pkl_84.npy',
#  'dumps/fullscale_trained_blmart.pkl_85.npy',
#  'dumps/fullscale_trained_blmart.pkl_86.npy',
#  'dumps/fullscale_trained_blmart.pkl_87.npy',
#  'dumps/fullscale_trained_blmart.pkl_88.npy',
#  'dumps/fullscale_trained_blmart.pkl_89.npy',
#  'dumps/fullscale_trained_blmart.pkl_90.npy',
#  'dumps/fullscale_trained_blmart.pkl_91.npy',
#  'dumps/fullscale_trained_blmart.pkl_92.npy',
#  'dumps/fullscale_trained_blmart.pkl_93.npy',
#  'dumps/fullscale_trained_blmart.pkl_94.npy',
#  'dumps/fullscale_trained_blmart.pkl_95.npy',
#  'dumps/fullscale_trained_blmart.pkl_96.npy',
#  'dumps/fullscale_trained_blmart.pkl_97.npy',
#  'dumps/fullscale_trained_blmart.pkl_98.npy',
#  'dumps/fullscale_trained_blmart.pkl_99.npy',
#  'dumps/fullscale_trained_blmart.pkl_100.npy',
#  'dumps/fullscale_trained_blmart.pkl_101.npy',
#  'dumps/fullscale_trained_blmart.pkl_102.npy',
#  'dumps/fullscale_trained_blmart.pkl_103.npy',
#  'dumps/fullscale_trained_blmart.pkl_104.npy',
#  'dumps/fullscale_trained_blmart.pkl_105.npy',
#  'dumps/fullscale_trained_blmart.pkl_106.npy',
#  'dumps/fullscale_trained_blmart.pkl_107.npy',
#  'dumps/fullscale_trained_blmart.pkl_108.npy',
#  'dumps/fullscale_trained_blmart.pkl_109.npy',
#  'dumps/fullscale_trained_blmart.pkl_110.npy',
#  'dumps/fullscale_trained_blmart.pkl_111.npy',
#  'dumps/fullscale_trained_blmart.pkl_112.npy',
#  'dumps/fullscale_trained_blmart.pkl_113.npy',
#  'dumps/fullscale_trained_blmart.pkl_114.npy',
#  'dumps/fullscale_trained_blmart.pkl_115.npy',
#  'dumps/fullscale_trained_blmart.pkl_116.npy',
#  'dumps/fullscale_trained_blmart.pkl_117.npy',
#  'dumps/fullscale_trained_blmart.pkl_118.npy',
#  'dumps/fullscale_trained_blmart.pkl_119.npy',
#  'dumps/fullscale_trained_blmart.pkl_120.npy',
#  'dumps/fullscale_trained_blmart.pkl_121.npy',
#  'dumps/fullscale_trained_blmart.pkl_122.npy',
#  'dumps/fullscale_trained_blmart.pkl_123.npy',
#  'dumps/fullscale_trained_blmart.pkl_124.npy',
#  'dumps/fullscale_trained_blmart.pkl_125.npy',
#  'dumps/fullscale_trained_blmart.pkl_126.npy',
#  'dumps/fullscale_trained_blmart.pkl_127.npy',
#  'dumps/fullscale_trained_blmart.pkl_128.npy',
#  'dumps/fullscale_trained_blmart.pkl_129.npy',
#  'dumps/fullscale_trained_blmart.pkl_130.npy',
#  'dumps/fullscale_trained_blmart.pkl_131.npy',
#  'dumps/fullscale_trained_blmart.pkl_132.npy',
#  'dumps/fullscale_trained_blmart.pkl_133.npy',
#  'dumps/fullscale_trained_blmart.pkl_134.npy',
#  'dumps/fullscale_trained_blmart.pkl_135.npy',
#  'dumps/fullscale_trained_blmart.pkl_136.npy',
#  'dumps/fullscale_trained_blmart.pkl_137.npy',
#  'dumps/fullscale_trained_blmart.pkl_138.npy',
#  'dumps/fullscale_trained_blmart.pkl_139.npy',
#  'dumps/fullscale_trained_blmart.pkl_140.npy',
#  'dumps/fullscale_trained_blmart.pkl_141.npy',
#  'dumps/fullscale_trained_blmart.pkl_142.npy',
#  'dumps/fullscale_trained_blmart.pkl_143.npy',
#  'dumps/fullscale_trained_blmart.pkl_144.npy',
#  'dumps/fullscale_trained_blmart.pkl_145.npy',
#  'dumps/fullscale_trained_blmart.pkl_146.npy',
#  'dumps/fullscale_trained_blmart.pkl_147.npy',
#  'dumps/fullscale_trained_blmart.pkl_148.npy',
#  'dumps/fullscale_trained_blmart.pkl_149.npy',
#  'dumps/fullscale_trained_blmart.pkl_150.npy',
#  'dumps/fullscale_trained_blmart.pkl_151.npy',
#  'dumps/fullscale_trained_blmart.pkl_152.npy',
#  'dumps/fullscale_trained_blmart.pkl_153.npy',
#  'dumps/fullscale_trained_blmart.pkl_154.npy',
#  'dumps/fullscale_trained_blmart.pkl_155.npy',
#  'dumps/fullscale_trained_blmart.pkl_156.npy',
#  'dumps/fullscale_trained_blmart.pkl_157.npy',
#  'dumps/fullscale_trained_blmart.pkl_158.npy',
#  'dumps/fullscale_trained_blmart.pkl_159.npy',
#  'dumps/fullscale_trained_blmart.pkl_160.npy',
#  'dumps/fullscale_trained_blmart.pkl_161.npy',
#  'dumps/fullscale_trained_blmart.pkl_162.npy',
#  'dumps/fullscale_trained_blmart.pkl_163.npy',
#  'dumps/fullscale_trained_blmart.pkl_164.npy',
#  'dumps/fullscale_trained_blmart.pkl_165.npy',
#  'dumps/fullscale_trained_blmart.pkl_166.npy',
#  'dumps/fullscale_trained_blmart.pkl_167.npy',
#  'dumps/fullscale_trained_blmart.pkl_168.npy',
#  'dumps/fullscale_trained_blmart.pkl_169.npy',
#  'dumps/fullscale_trained_blmart.pkl_170.npy',
#  'dumps/fullscale_trained_blmart.pkl_171.npy',
#  'dumps/fullscale_trained_blmart.pkl_172.npy',
#  'dumps/fullscale_trained_blmart.pkl_173.npy',
#  'dumps/fullscale_trained_blmart.pkl_174.npy',
#  'dumps/fullscale_trained_blmart.pkl_175.npy',
#  'dumps/fullscale_trained_blmart.pkl_176.npy',
#  'dumps/fullscale_trained_blmart.pkl_177.npy',
#  'dumps/fullscale_trained_blmart.pkl_178.npy',
#  'dumps/fullscale_trained_blmart.pkl_179.npy',
#  'dumps/fullscale_trained_blmart.pkl_180.npy',
#  'dumps/fullscale_trained_blmart.pkl_181.npy']
